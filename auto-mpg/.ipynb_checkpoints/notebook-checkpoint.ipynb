# %% [markdown]
# # Auto-MPG
# ---

# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Download the data

# %%
df = pd.read_csv('files/datasets/auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Take a Quick Look at the Data

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.hist(bins=50, figsize=(15,10))
plt.show()

# %% [markdown]
# ## Pandas Pipeline

# %%
# Pipe 1

def num_prefix(dataframe, str_column):
    
    # Apply function if the year is not in 19-- format    
    if (dataframe[str_column] < 1000).all():
        
        # Apply prefix concatenation to the number   
        dataframe[str_column] = dataframe[str_column].apply(lambda x: 1900 + x)
    
    else:
        pass
    
    return dataframe

# %%
# Pipe 2

def first_word_extract(dataframe, column, new_colname):
    
    # Change data type into string
    dataframe[column] = dataframe[column].astype('str')
    
    # Split converted string and store it in a series
    col_data = pd.Series(dtype='object')
    col_data['phrase_aslist'] = dataframe[column].str.split()
    
    # Retrieve the first content in the splitted phrase contained as a list
    dataframe[new_colname] = col_data['phrase_aslist'].apply(lambda words_aslist: words_aslist[0])
    
    return dataframe

# %%
# Pipe 3

def replace_char(dataframe, column, dict_replace):
    dataframe[column] = dataframe[column].replace(dict_replace)
    
    # Optional: Change data type into a float
    dataframe[column] = dataframe[column].astype('float64')
    
    return dataframe

# %%
df_pipe = (df.pipe(num_prefix, 'model year')
             .pipe(first_word_extract, 'car name', 'car brand')
             .pipe(replace_char, 'horsepower', {'?': np.nan})
          )

# %%
df_pipe['car brand'].value_counts()
# Out:
# ford             51
# chevrolet        43
# plymouth         31
# amc              28
# dodge            28
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# mazda            10
# oldsmobile       10
# fiat              8
# peugeot           8
# audi              7
# chrysler          6
# vw                6
# volvo             6
# renault           5
# saab              4
# subaru            4
# opel              4
# chevy             3
# bmw               2
# cadillac          2
# maxda             2
# mercedes-benz     2
# triumph           1
# vokswagen         1
# mercedes          1
# hi                1
# capri             1
# chevroelt         1
# toyouta           1
# nissan            1
# Name: car brand, dtype: int64

# %%
rename_dict= {'toyouta': 'toyota', 
              'maxda': 'mazda', 
              'chevroelt': 'chevrolet', 
              'vw': 'volkswagen',
              'vokswagen': 'volkswagen', 
              'chevy': 'chevrolet', 
              'mercedes': 'mercedes-benz',
              'capri': 'ford'}

df_pipe['car brand'] = df_pipe['car brand'].replace(rename_dict)

df_remove = df_pipe[df_pipe['car brand'].isin(['nissan', 'hi', 'triumph'])]
df_pipe = df_pipe.drop(df_remove.index)

# %%
df_pipe['car brand'].value_counts()
# Out:
# ford             52
# chevrolet        47
# plymouth         31
# amc              28
# dodge            28
# toyota           26
# datsun           23
# volkswagen       22
# buick            17
# pontiac          16
# honda            13
# mazda            12
# mercury          11
# oldsmobile       10
# fiat              8
# peugeot           8
# audi              7
# volvo             6
# chrysler          6
# renault           5
# saab              4
# opel              4
# subaru            4
# mercedes-benz     3
# bmw               2
# cadillac          2
# Name: car brand, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# ### Split data as stratified

# %%
df_pipe["mpg_cat"] = pd.cut(df_pipe["mpg"],
                       bins=[0, 20, 30, 40, np.inf],
                       labels=['Poor', 'Fair', 'Good', 'Excellent'])

# %%
def plot_bins(dataframe, cat_column, x_axis_name, y_axis_name):
    
    cat_count = dataframe[cat_column].value_counts()
    cat_count.sort_index().plot.bar(rot=0, grid=True)
    
    plt.xlabel(x_axis_name)
    plt.ylabel(y_axis_name)
    
    return plt.show()

plot_bins(df_pipe, 'mpg_cat', 'Mileage Rating', 'Number of Vehicles')

# %%
strat_train_set, strat_test_set = train_test_split(df_pipe, test_size=0.2, stratify=df_pipe["mpg_cat"], random_state=42)

# Check stratification of splitted data
strat_test_set["mpg_cat"].value_counts() / len(strat_test_set)

# Check stratification of original data
# df["mpg_cat"].value_counts() / len(df)
# Out:
# Poor         0.405063
# Fair         0.379747
# Good         0.189873
# Excellent    0.025316
# Name: mpg_cat, dtype: float64

# %%
mpg_df = strat_train_set.copy()

# %% [markdown]
# ---

# %%
mpg_df.hist(bins=50, figsize=(15,10))
plt.show()

# %%
# Split into features and target

def xy_split(dataframe, y_column):
    features = dataframe.loc[:, dataframe.columns != y_column]
    target = dataframe[y_column]
    
    # X_train, y_train
    return features, target

X_train, y_train = xy_split(strat_train_set, 'mpg')
X_test, y_test = xy_split(strat_test_set, 'mpg')

# %%
mpg_df.select_dtypes(include='float64').hist(bins=40, figsize=(15,10))
plt.show()

# %%
for i in mpg_df.select_dtypes(include='float64'):
    print(f'Skeweness of {mpg_df[i].skew().round(5)} for {i}')
# Out:
# Skeweness of 0.50096 for mpg
# Skeweness of 0.68731 for displacement
# Skeweness of 1.01376 for horsepower
# Skeweness of 0.34052 for acceleration

# %%
import pandas as pd

def impute_central_tendency(dataframe, column):
    central_tendency = ["mean", "median", "mode"]
    impute_df = pd.DataFrame()
    impute_column = dataframe[column]
    
    # Impute null values using cental tendency
    for stat in central_tendency:
        if stat == "mode":
            impute_df[stat] = eval(f"impute_column.fillna(value=impute_column.mode()[0])")
        else:
            impute_df[stat] = eval(f"impute_column.fillna(value=impute_column.{stat}())")
            
    # Round all answers to nearest integer
    round_impute = impute_df.round(0).astype(int)
    
    return round_impute

# %%
def skew(dataframe):
    # Create a dataframe with index names
    df = pd.DataFrame(index=['mean', 'median', 'mode'])

    # Columns to the dataframe
    df['raw_skew'] = [dataframe[i].skew() for i in dataframe.columns]
    df['log_skew'] = [dataframe[i].apply(np.log).skew() for i in dataframe.columns]
    df['sqrt_skew'] = [dataframe[i].apply(np.sqrt).skew() for i in dataframe.columns]
    df['cbrt_skew'] = [dataframe[i].apply(np.cbrt).skew() for i in dataframe.columns]
    df['log1p_skew'] = [dataframe[i].apply(np.log1p).skew() for i in dataframe.columns]

    return df

# Argument must be a dataframe that contains mean, median and mode as the columns

# %%
new = skew(impute_central_tendency(mpg_df, 'horsepower'))
new
# Out:
#         raw_skew  log_skew  sqrt_skew  cbrt_skew  log1p_skew
# mean    1.021787  0.293824   0.667124   0.545178    0.301712
# median  1.032595  0.308146   0.680259   0.558861    0.316031
# mode    0.956970  0.262797   0.618456   0.502334    0.270332

# %%
params = {'dataframe':         mpg_df,
          'column':            'horsepower',
          'bins':              15,
          'equation':          np.log}

def before_after_transform(dataframe, column, bins, equation):
    fig, axis = plt.subplots(1, 2, figsize=(8, 3), sharey=True)
    dataframe[column].hist(ax=axis[0], bins=bins)
    dataframe[column].apply(equation).hist(ax=axis[1], bins=bins)

    # Set labels
    axis[0].set_xlabel(column)
    axis[1].set_xlabel(f'log of {column}')
    axis[0].set_ylabel(f'{column} histogram')
    
    return plt.show()

before_after_transform(**params)

# %% [markdown]
# Acceleration: np.sqrt Transformation <br>
# Displacement: np.log Transformation <br>
# Weight: np.log Transformation <br>
# mpg: np.log1p Transformation

# %% [markdown]
# ---

# %% [markdown]
# ## One hot encoding for car brands

# %%
from sklearn import set_config
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer, StandardScaler
from sklearn.tree import DecisionTreeRegressor


set_config(transform_output="pandas")

# %%
class FrequencyEncoder(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        # Calculate the frequency of each category
        self.encoders_ = {}
        for col in X.columns:
            self.encoders_[col] = X[col].value_counts()
        return self

    def transform(self, X):
        # Encode the categories as the frequencies of the categories
        X_encoded = X.apply(lambda col: col.map(self.encoders_[col.name]))
        return X_encoded

# %%
imputer = SimpleImputer(strategy="median")
freq_imp = SimpleImputer(strategy="most_frequent")
log_transformer = FunctionTransformer(np.log, feature_names_out="one-to-one")
sqrt_transformer = FunctionTransformer(np.sqrt, feature_names_out="one-to-one")
freq_enc = FrequencyEncoder()
scaler = StandardScaler()

# %%
log_pipeline = make_pipeline(imputer, log_transformer, scaler)
sqrt_pipeline = make_pipeline(imputer, sqrt_transformer, scaler)
cat_pipeline = make_pipeline(freq_imp, freq_enc, scaler)
horsepower_pipe = make_pipeline(freq_imp, log_transformer, scaler)
int64_pipe = make_pipeline(freq_imp, scaler)

# %%
process = ColumnTransformer([
    ('integer', int64_pipe, make_column_selector(dtype_include='int64')),
    ("log", log_pipeline, ['weight', 'displacement']),
    ("sqrt", sqrt_pipeline, ['acceleration']),
    ("cat", cat_pipeline, ['car brand']), 
    ("hp", horsepower_pipe, ['horsepower'])
])

# %% [markdown]
# ---

# %% [markdown]
# # Train Models

# %%
from sklearn.linear_model import LinearRegression

lin_reg = make_pipeline(process, LinearRegression())
lin_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('integer',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000020C2B33C190>),
#                                                  ('log',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')...
#                                                                   ('frequencyencoder',
#                                                                    FrequencyEncoder()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['car brand']),
#                                                  ('hp',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('functiontransformer',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<ufunc 'log'>)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['horsepower'])])),
#                 ('linearregression', LinearRegression())])

# %%
predictions = lin_reg.predict(X_train)

lin_rmse = mean_squared_error(y_train, predictions, squared=False)
lin_rmse
# Out:
# 2.9462981280210574

# %% [markdown]
# ### Decision Tree Regressor

# %%
tree_reg = make_pipeline(process, DecisionTreeRegressor(random_state=42))
tree_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('integer',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x0000020C2B33C190>),
#                                                  ('log',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')...
#                                                                    FrequencyEncoder()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['car brand']),
#                                                  ('hp',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('functiontransformer',
#                                                                    FunctionTransformer(feature_names_out='one-to-one',
#                                                                                        func=<ufunc 'log'>)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['horsepower'])])),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(random_state=42))])

# %%
housing_predictions = tree_reg.predict(X_train)
tree_rmse = mean_squared_error(y_train, housing_predictions,
                              squared=False)
tree_rmse
# Out:
# 0.0

# %% [markdown]
# ----

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

tree_rmses = -cross_val_score(tree_reg, X_train, y_train,
                              scoring="neg_root_mean_squared_error", cv=10)

# %%
pd.Series(tree_rmses).describe()
# Out:
# count    10.000000
# mean      3.504495
# std       1.159872
# min       2.346473
# 25%       2.819729
# 50%       3.000528
# 75%       4.082577
# max       5.997031
# dtype: float64

# %%
# Linear Regression

# extra code – computes the error stats for the linear model
lin_rmses = -cross_val_score(lin_reg, X_train, y_train,
                              scoring="neg_root_mean_squared_error", cv=10)
pd.Series(lin_rmses).describe()
# Out:
# count    10.000000
# mean      3.060869
# std       0.474584
# min       2.350320
# 25%       2.742334
# 50%       2.964107
# 75%       3.424767
# max       3.808988
# dtype: float64
